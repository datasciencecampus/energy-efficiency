# %% [markdown]
# # CHAID

# %% [markdown]
# The EPC data contains several categorical variables with a lot of values. In order to find suitable features which will retain the most information, three feature sets are explored;
# * data driven
# * domain driven
# * exhaustive
#
# The first approach, termed data driven, uses statistical methods to reduce the number of variables. As the variables containing textual descriptions of the property have been created free-hand, many contain a large number of unique values. In some cases, only recorded for one property. The data driven approach uses a single level Chi-square Automatic Interaction Detector (CHAID) to group the levels within each categorical variable into a smaller number of groups. CHAID groups values with a similar response rate or in this context Energy Efficiency Rating (EER).
#
# This script run CHAID and stores the results in a dictionary

# %%
import numpy as np
import pandas as pd
import datetime
import os
import glob
import json
from CHAID import Tree
import re

# %%
# set variables from config file
config_path = os.path.abspath('..')[:-7]

with open(config_path + '/config.json', 'r') as f:
    config = json.load(f)

processing_path = config['DEFAULT']['processing_path']
epc_train_fname = config['DEFAULT']['epc_train_fname']
epc_test_fname = config['DEFAULT']['epc_test_fname']
epc_train_clean_fname = config['DEFAULT']['epc_train_clean_fname']
epc_chaid_fname = config['DEFAULT']['epc_chaid_fname']

# %%
dtype_dict = {'INSPECTION_DATE':'str'}

epc_train = pd.read_csv(os.path.join(processing_path,epc_train_clean_fname),
                        header = 0,
                        delimiter = ',',
                        dtype = dtype_dict,
                        parse_dates = ['INSPECTION_DATE'])

# %%
#Get quantile boundafries
quantiles = epc_train['CURRENT_ENERGY_EFFICIENCY'].describe()
print(quantiles['25%'])
print(quantiles['75%'])
# Out:
# 52.0
# 71.0

# %%
#Create a new new target field within the training data
min_eff = epc_train['CURRENT_ENERGY_EFFICIENCY'].min()
max_eff = epc_train['CURRENT_ENERGY_EFFICIENCY'].max()
epc_train['eff_flag'] = pd.cut(epc_train['CURRENT_ENERGY_EFFICIENCY'],
                               bins = [min_eff,53.0,71.0,max_eff],
                               labels = ['0','99','1'])

#Drop unwated '99' level of eff_flag and convert to integer
epc_train = epc_train[epc_train['eff_flag'].isin(['0','1'])]
epc_train['eff_flag'] = epc_train['eff_flag'].astype(int)

# %%
#Get the {0,1} sample size by taking the smallest class from the 0
#and 1 outcomes
sample_size = epc_train['eff_flag'].value_counts().min()


#Subsample positive and negative samples
neg_eff_flag = epc_train[epc_train['eff_flag'] == 0].sample(sample_size,random_state = 1234,axis = 0)

pos_eff_flag = epc_train[epc_train['eff_flag'] == 1].sample(sample_size,random_state = 1234,axis = 0)

#Concatenate
epc_chaid = pd.concat([neg_eff_flag, pos_eff_flag])
epc_chaid['eff_flag'].value_counts()

#Randomly shuffle epc_CHAID and reset the index
epc_chaid = epc_chaid.sample(frac = 1).reset_index(drop=True)

# %%
#Numeric
var_list_num = epc_chaid.select_dtypes(include= 'number').columns.tolist()
var_list_num.remove('CURRENT_ENERGY_EFFICIENCY')

#Categorical
var_list_cat = epc_chaid.select_dtypes(include= ['object','category']).columns.tolist()
var_list_cat.remove('LMK_KEY')
var_list_cat.remove('POSTCODE')
var_list_cat.remove('CURRENT_ENERGY_RATING')
var_list_cat.remove('LODGEMENT_DATE')

# %% [markdown]
# ### Creating a dictionary of CHAID scores

# %%
chaid_dict = {}
for var in var_list_cat:
    #Set the inputs and outputs
    #The imputs are given as a dictionary along with the type
    #The output must be of string type
    #I have assume all features are nominal, we can change the features dictionary to include the ordinal type
    features = {var:'nominal'}
    label = 'eff_flag'
    #Create the Tree
    chaid_dict[var] = {}
    tree = Tree.from_pandas_df(epc_chaid, i_variables = features, d_variable = label, alpha_merge = 0.0)
    #Loop through all the nodes and enter into a dictionary
    print('\n\n\nVariable: %s' % var)
    print('p-value: %f' % tree.tree_store[0].split.p)
    print('Chi2: %f' % tree.tree_store[0].split.score)
    for i in range(1, len(tree.tree_store)):
        count = tree.tree_store[i].members[0] + tree.tree_store[i].members[1]
        rate = tree.tree_store[i].members[1] / count
        print('\nNode %i:\n\tCount = %i\tRate = %f' % (i,count,rate))
        print('\t%s' % tree.tree_store[i].choices)
        chaid_dict[var]['node' + str(i)] = tree.tree_store[i].choices
# Out:
# Variable: region
# p-value: 0.000000
# Chi2: 14047.791587
#
# Node 1:
# 	Count = 93959	Rate = 0.424217
# 	['Blaenau Gwent', 'Pembrokeshire', 'Rhondda Cynon Taf', 'Neath Port Talbot', 'Carmarthenshire', 'Powys', 'Conwy']
#
# Node 2:
# 	Count = 96951	Rate = 0.551124
# 	['Bridgend', 'Wrexham', 'Monmouthshire', 'Merthyr Tydfil', 'Vale of Glamorgan', 'Caerphilly', 'Flintshire', 'Swansea']
#
# Node 3:
# 	Count = 57894	Rate = 0.656027
# 	['Cardiff', 'Torfaen', 'Newport']
#
# Node 4:
# 	Count = 36030	Rate = 0.309353
# 	['Ceredigion', 'Debighshire', 'Gwynedd', 'Isle of Anglesey']
#
#
#
# Variable: PROPERTY_TYPE
# p-value: 0.000000
# Chi2: 34442.140161
#
# Node 1:
# 	Count = 26988	Rate = 0.273158
# 	['Bungalow', 'Park home']
#
# Node 2:
# 	Count = 61090	Rate = 0.821051
# 	['Flat']
#
# Node 3:
# 	Count = 196756	Rate = 0.431433
# 	['House', 'Maisonette']
#
#
#
# Variable: BUILT_FORM
# p-value: 0.000000
# Chi2: 6688.231114
#
# Node 1:
# 	Count = 20896	Rate = 0.772301
# 	['<missing>', 'Enclosed End-Terrace', 'Enclosed Mid-Terrace']
#
# Node 2:
# 	Count = 263938	Rate = 0.478442
# 	['End-Terrace', 'Mid-Terrace', 'Semi-Detached', 'Detached']
#
#
#
# Variable: TRANSACTION_TYPE
# p-value: 0.000000
# Chi2: 96131.250603
#
# Node 1:
# 	Count = 51469	Rate = 0.434941
# 	['<missing>', 'rental', 'rental (private)', 'following green deal', 'rental (private) - this is for backwards compatibility only and should not be used']
#
# Node 2:
# 	Count = 128430	Rate = 0.290508
# 	['none of the above', 'RHI application', 'non marketed sale', 'marketed sale']
#
# Node 3:
# 	Count = 48823	Rate = 0.859902
# 	['rental (social)', 'FiT application']
#
# Node 4:
# 	Count = 16973	Rate = 0.118247
# 	['assessment for green deal', 'ECO assessment']
#
# Node 5:
# 	Count = 39139	Rate = 0.989576
# 	['rental (social) - this is for backwards compatibility only and should not be used', 'new dwelling']
#
#
#
# Variable: ENERGY_TARIFF
# p-value: 0.000000
# Chi2: 47456.179527
#
# Node 1:
# 	Count = 22415	Rate = 0.557172
# 	['<missing>', 'off-peak 18 hour']
#
# Node 2:
# 	Count = 221888	Rate = 0.404546
# 	['dual', 'dual (24 hour)', 'Single']
#
# Node 3:
# 	Count = 40531	Rate = 0.990945
# 	['off-peak 10 hour', 'off-peak 7 hour', '24 hour', 'standard tariff']
#
#
#
# Variable: MAINS_GAS_FLAG
# p-value: 0.000000
# Chi2: 51651.004453
#
# Node 1:
# 	Count = 47839	Rate = 0.914129
# 	['<missing>']
#
# Node 2:
# 	Count = 63888	Rate = 0.229605
# 	['N']
#
# Node 3:
# 	Count = 173107	Rate = 0.485347
# 	['Y']
#
#
#
# Variable: FLOOR_LEVEL
# p-value: 0.000000
# Chi2: 30558.556373
#
# Node 1:
# 	Count = 218197	Rate = 0.411921
# 	['<missing>', '21st or above']
#
# Node 2:
# 	Count = 56663	Rate = 0.755731
# 	['4th', '8th', '11th', '13th', '10th', '5th', '7th', '17th', '6th', '3rd', 'Ground', '9th', '14th', 'Basement', '1st', '2nd']
#
# Node 3:
# 	Count = 9974	Rate = 0.974032
# 	['15th', '16th', '12th', '18th', '20th', '19th', 'top floor', 'ground floor', 'mid floor']
#
#
#
# Variable: MAIN_HEATING_CONTROLS
# p-value: 0.000000
# Chi2: 111832.727779
#
# Node 1:
# 	Count = 109171	Rate = 0.766596
# 	['<missing>', 'control for high heat retention storage heaters', 'programmer, trvs and flow switch', 'flat rate charging, programmer, no room thermostat', 'flat rate charging, programmer and at least two room thermostat', 'temperature zone control', 'programmer, room thermostat and trvs', 'flat rate charging, no thermostat control']
#
# Node 2:
# 	Count = 41901	Rate = 0.029784
# 	['programmer, no room thermostat', 'no thermostat control', 'no time or thermostat control of room temperature', 'not relevant (supplies dhw only)', 'none']
#
# Node 3:
# 	Count = 9900	Rate = 0.535354
# 	['programmer and at least two room thermostat', 'programmer and appliance thermostat', 'automatic charge control', 'programmer, trvs and boiler energy manager']
#
# Node 4:
# 	Count = 25914	Rate = 0.977927
# 	['charging system linked to use of community heating, programmer and trvs', 'celect control', 'charging system linked to use of community heating, room thermostat only', '2207 time and temperature zone control', 'programmer and at least two room thermostat including a delayed start thermostat', 'charging linked to use, programmer and trvs', 'charging system linked to use of community heating, programmer and at least two room thermostat', 'delayed start thermostat, programmer and trvs', 'trvs, programmer and flow switch', 'unit charging, programmer and trvs', 'time and temperature zone control', 'flat rate charging, programmer and trvs', 'flat rate charging, programmer and room thermostat', 'flat rate charging, room thermostat only', 'charging system linked to use of community heating, trvs', 'flat rate charging, trvs', 'celect-type control', 'charging system linked to use of community heating, programmer and room thermostat']
#
# Node 5:
# 	Count = 97948	Rate = 0.273992
# 	['room thermostat only', 'programmer, trvs and bypass', 'trvs and bypass', 'programmer and room thermostat', 'appliance thermostat', 'manual charge control']
#
#
#
# Variable: GLAZED_TYPE
# p-value: 0.000000
# Chi2: 51548.889357
#
# Node 1:
# 	Count = 59138	Rate = 0.772261
# 	['<missing>', 'double, known data', 'triple, known data']
#
# Node 2:
# 	Count = 78014	Rate = 0.671841
# 	['double glazing installed during or after 2002', 'triple glazing']
#
# Node 3:
# 	Count = 50735	Rate = 0.237449
# 	['INVALID!', 'double glazing, unknown install date', 'single glazing', 'secondary glazing']
#
# Node 4:
# 	Count = 96947	Rate = 0.333038
# 	['double glazing installed before 2002']
#
#
#
# Variable: HOTWATER_DESCRIPTION
# p-value: 0.000000
# Chi2: 58495.540130
#
# Node 1:
# 	Count = 199294	Rate = 0.609005
# 	['<missing>', 'From main system, standard tariff', 'No system present: electric immersion assumed, plus solar', 'Electric immersion, dual tariff', 'Gas boiler/circulator, plus solar', 'From main system']
#
# Node 2:
# 	Count = 8485	Rate = 0.927873
# 	['Community scheme, no cylinderstat', 'Community scheme', 'Community scheme, plus solar', 'Electric immersion', 'From main system, flue gas heat recovery, plus solar', 'Electric immersion, standard tariff, plus solar, waste water heat recovery', 'From main system, plus solar, waste water heat recovery', 'Electric instantaneous at point of use, no cylinderstat', 'Electric heat pump', 'Heat pump, waste water heat recovery', 'From main system, 7-hour tariff (on-peak)', 'Electric heat pump, plus solar', 'Oil boiler/circulator, waste water heat recovery', 'Electric instantaneous at point of use, waste water heat recovery', 'Electric heat pump for water heating only', 'From main system, flue gas heat recovery, waste water heat recovery', 'Community scheme with CHP', 'Oil boiler/circulator, plus solar, waste water heat recovery', 'Community scheme, no cylinderstat, plus solar', 'From main system, no cylinderstat, flue gas heat recovery', 'From main system, flue gas heat recovery', 'From main system, waste water heat recovery', 'From main system, plus solar', 'Oil boiler/circulator, plus solar']
#
# Node 3:
# 	Count = 38968	Rate = 0.034515
# 	['Electric immersion, standard tariff, no cylinderstat', 'Room heaters, dual fuel (mineral and wood)', 'Back boiler (hot water only), gas', 'Single-point gas water heater', 'No system present: electric immersion assumed, no cylinderstat', 'Gas range cooker, no cylinderstat', 'Room heaters, anthracite', 'Room heaters, oil', 'Single-point gas water heater, standard tariff', 'Solid fuel range cooker', 'Gas multipoint, no cylinderstat', 'Solid fuel range cooker, no cylinderstat, plus solar', 'Gas boiler/circulator, no cylinderstat', 'Oil range cooker, plus solar', 'Room heaters, smokeless fuel', 'Electric multipoint', ', no cylinderstat', 'Solid fuel boiler/circulator, plus solar', 'Oil range cooker, no cylinderstat, plus solar', 'Single-point gas water heater, off-peak', 'Electric instantaneous at point of use, plus solar', 'underfloor heating, standard tariff', 'Room heaters, coal', 'Room heaters, LPG', 'From secondary system, no cylinderstat', 'Solid fuel range cooker, no cylinderstat', 'Oil range cooker, no cylinderstat', 'From main system, no cylinderstat', 'Oil range cooker', 'Solid fuel boiler/circulator', 'Room heaters,', 'Solid fuel boiler/circulator, no cylinderstat', 'Room heaters, wood logs']
#
# Node 4:
# 	Count = 91	Rate = 0.000000
# 	['Electric immersion, standard tariff, no cylinderstat']
#
# Node 5:
# 	Count = 90	Rate = 0.000000
# 	['Room heaters, dual fuel (mineral and wood)']
#
# Node 6:
# 	Count = 2	Rate = 0.000000
# 	['Back boiler (hot water only), gas']
#
# Node 7:
# 	Count = 1	Rate = 0.000000
# 	['Single-point gas water heater']
#
# Node 8:
# 	Count = 10	Rate = 0.000000
# 	['No system present: electric immersion assumed, no cylinderstat']
#
# Node 9:
# 	Count = 37031	Rate = 0.035808
# 	['From main system, no cylinderstat']
#
# Node 10:
# 	Count = 29	Rate = 0.000000
# 	['Gas range cooker, no cylinderstat']
#
# Node 11:
# 	Count = 5	Rate = 0.000000
# 	['Room heaters, anthracite']
#
# Node 12:
# 	Count = 8	Rate = 0.000000
# 	['Room heaters, oil']
#
# Node 13:
# 	Count = 8	Rate = 0.000000
# 	['Single-point gas water heater, standard tariff']
#
# Node 14:
# 	Count = 24	Rate = 0.041667
# 	['Room heaters,']
#
# Node 15:
# 	Count = 23	Rate = 0.000000
# 	['Solid fuel range cooker']
#
# Node 16:
# 	Count = 2	Rate = 0.000000
# 	['Gas multipoint, no cylinderstat']
#
# Node 17:
# 	Count = 2	Rate = 0.000000
# 	['Solid fuel range cooker, no cylinderstat, plus solar']
#
# Node 18:
# 	Count = 104	Rate = 0.000000
# 	['Gas boiler/circulator, no cylinderstat']
#
# Node 19:
# 	Count = 1	Rate = 0.000000
# 	['Oil range cooker, plus solar']
#
# Node 20:
# 	Count = 18	Rate = 0.000000
# 	['Room heaters, smokeless fuel']
#
# Node 21:
# 	Count = 80	Rate = 0.037500
# 	['Oil range cooker']
#
# Node 22:
# 	Count = 19	Rate = 0.000000
# 	['Electric multipoint']
#
# Node 23:
# 	Count = 583	Rate = 0.006861
# 	['From secondary system, no cylinderstat']
#
# Node 24:
# 	Count = 2	Rate = 0.000000
# 	[', no cylinderstat']
#
# Node 25:
# 	Count = 48	Rate = 0.041667
# 	['Solid fuel boiler/circulator, no cylinderstat']
#
# Node 26:
# 	Count = 2	Rate = 0.000000
# 	['Solid fuel boiler/circulator, plus solar']
#
# Node 27:
# 	Count = 3	Rate = 0.000000
# 	['Oil range cooker, no cylinderstat, plus solar']
#
# Node 28:
# 	Count = 186	Rate = 0.005376
# 	['Solid fuel range cooker, no cylinderstat']
#
# Node 29:
# 	Count = 1	Rate = 0.000000
# 	['Single-point gas water heater, off-peak']
#
# Node 30:
# 	Count = 51	Rate = 0.039216
# 	['Solid fuel boiler/circulator']
#
# Node 31:
# 	Count = 1	Rate = 0.000000
# 	['Electric instantaneous at point of use, plus solar']
#
# Node 32:
# 	Count = 70	Rate = 0.042857
# 	['Room heaters, wood logs']
#
# Node 33:
# 	Count = 4	Rate = 0.000000
# 	['underfloor heating, standard tariff']
#
# Node 34:
# 	Count = 92	Rate = 0.000000
# 	['Room heaters, coal']
#
# Node 35:
# 	Count = 14	Rate = 0.000000
# 	['Room heaters, LPG']
#
# Node 36:
# 	Count = 363	Rate = 0.008264
# 	['Oil range cooker, no cylinderstat']
#
# Node 37:
# 	Count = 19675	Rate = 0.458602
# 	['From secondary system, plus solar', 'Gas instantaneous at point of use', 'Electric immersion, off-peak, plus solar', 'Electric immersion, standard tariff, plus solar', 'Solid fuel range cooker, plus solar', 'Electric immersion, off-peak']
#
# Node 38:
# 	Count = 18412	Rate = 0.152346
# 	['Oil boiler/circulator, no cylinderstat', 'Oil boiler/circulator', 'From secondary system', 'No system present: electric immersion assumed', 'Gas range cooker', 'Room heaters, mains gas', 'Gas multipoint', 'Electric immersion, off-peak, no cylinderstat', 'Gas boiler/circulator', 'Electric immersion, standard tariff', 'Electric instantaneous at point of use', 'Room heaters, electric', 'underfloor heating, off-peak', 'From main system, no cylinderstat, plus solar', 'From secondary system, no cylinderstat, plus solar']
#
#
#
# Variable: HOT_WATER_ENERGY_EFF
# p-value: 0.000000
# Chi2: 99696.632305
#
# Node 1:
# 	Count = 139864	Rate = 0.697828
# 	['<missing>', 'Good']
#
# Node 2:
# 	Count = 48402	Rate = 0.285112
# 	['Average']
#
# Node 3:
# 	Count = 27136	Rate = 0.933004
# 	['Very Good']
#
# Node 4:
# 	Count = 69432	Rate = 0.082066
# 	['Very Poor', 'Poor']
#
#
#
# Variable: HOT_WATER_ENV_EFF
# p-value: 0.000000
# Chi2: 82614.861754
#
# Node 1:
# 	Count = 148200	Rate = 0.652928
# 	['<missing>', 'Good']
#
# Node 2:
# 	Count = 105963	Rate = 0.165463
# 	['Average', 'Very Poor', 'Poor']
#
# Node 3:
# 	Count = 30671	Rate = 0.916827
# 	['Very Good']
#
#
#
# Variable: FLOOR_DESCRIPTION
# p-value: 0.000000
# Chi2: 114957.356804
#
# Node 1:
# 	Count = 57981	Rate = 0.801659
# 	['<missing>', '(same dwelling below) insulated', 'average thermal transmittance 0.5 w/m²k', 'average thermal transmittance 0.9 w/m²k', 'to unheated space, limited insulation', 'average thermal transmittance 0.8 w/m²k', 'to unheated space, insulated', 'to external air, limited insulation', 'average thermal transmittance 0.4 w/m²k', 'suspended, insulated', 'to external air, insulated', 'other premises below', 'suspended, limited insulation', 'no insulation', 'solid, 25 mm insulation', 'solid, limited insulation']
#
# Node 2:
# 	Count = 143548	Rate = 0.291164
# 	['above heated space', 'average thermal transmittance 0.6 w/m²k', 'average thermal transmittance 2.6 w/m²k', 'average thermal transmittance 1.1 w/m²k', 'conservatory', 'solid, no insulation']
#
# Node 3:
# 	Count = 33159	Rate = 0.995265
# 	['average thermal transmittance 0.2 w/m²k', 'insulated', 'limited insulation', 'average thermal transmittance 2.0 w/m²k', 'average thermal transmittance 0.1 w/m²k']
#
# Node 4:
# 	Count = 30476	Rate = 0.085740
# 	['to external air, no insulation', 'to unheated space, no insulation', 'suspended, no insulation', 'average thermal transmittance 1.2 w/m²k', 'suspended, unsealed. no insulation', 'no heat loss floors', 'suspended', 'to unheated space,insulated', 'above partially heated space', 'average thermal transmittance 2.2 w/m²k', 'average thermal transmittance 2.1 w/m²k']
#
# Node 5:
# 	Count = 19670	Rate = 0.941790
# 	['solid, 75 mm insulation', 'average thermal transmittance 0.3 w/m²k', 'average thermal transmittance 0.0 w/m²k', 'solid, 100 mm insulation', 'solid, insulated', 'average thermal transmittance 1.0 w/m²k', 'average thermal transmittance 0.7 w/m²k']
#
#
#
# Variable: WINDOWS_DESCRIPTION
# p-value: 0.000000
# Chi2: 55605.109795
#
# Node 1:
# 	Count = 211578	Rate = 0.526033
# 	['<missing>', 'multiple glazing throughout', 'full triple glazing', 'full double glazing']
#
# Node 2:
# 	Count = 46912	Rate = 0.104984
# 	['single glazing and secondary glazing', 'single and multiple glazing', 'some multiple glazing', 'single glazing', 'mostly triple glazing', 'full secondary glazing', 'double glazing', 'partial secondary glazing', 'mostly multiple glazing', 'single glazing and double glazing', 'secondary glazing', 'mostly double glazing', 'partial double glazing', 'partial multiple glazing', 'partial triple glazing', 'single glazingtriple glazing', 'unknown complex glazing regime', 'solid, no insulation (assumed)', 'some triple glazing', 'mostly secondary glazing', 'some secondary glazing', 'some double glazing']
#
# Node 3:
# 	Count = 26344	Rate = 0.994344
# 	['high performance glazing']
#
#
#
# Variable: WINDOWS_ENERGY_EFF
# p-value: 0.000000
# Chi2: 85592.748666
#
# Node 1:
# 	Count = 95057	Rate = 0.737610
# 	['<missing>', 'Good']
#
# Node 2:
# 	Count = 127229	Rate = 0.325453
# 	['Average']
#
# Node 3:
# 	Count = 27429	Rate = 0.992708
# 	['Very Good']
#
# Node 4:
# 	Count = 35119	Rate = 0.104388
# 	['Very Poor', 'Poor']
#
#
#
# Variable: WINDOWS_ENV_EFF
# p-value: 0.000000
# Chi2: 85592.748666
#
# Node 1:
# 	Count = 95057	Rate = 0.737610
# 	['<missing>', 'Good']
#
# Node 2:
# 	Count = 127229	Rate = 0.325453
# 	['Average']
#
# Node 3:
# 	Count = 27429	Rate = 0.992708
# 	['Very Good']
#
# Node 4:
# 	Count = 35119	Rate = 0.104388
# 	['Very Poor', 'Poor']
#
#
#
# Variable: WALLS_DESCRIPTION
# p-value: 0.000000
# Chi2: 178552.122187
#
# Node 1:
# 	Count = 57140	Rate = 0.736909
# 	['<missing>', 'cavity wall, filled cavity + cavity wall, insulated', 'granite or whinstone, insulated', 'sandstone, insulated + cavity wall, insulated', 'timber frame, filled cavity', 'granite or whinstone, insulated + solid brick, insulated', 'average thermal transmittance 1.2 w/m²k', 'average thermal transmittance 1.1 w/m²k', 'cavity wall, filled cavity + cavity wall, partial insulation', 'average thermal transmittance 1.3 w/m²k', 'timber frame, partial insulation', 'system built, partial insulation', 'sandstone or limestone, insulated', 'timber frame, insulated + cavity wall, insulated', 'cavity wall, filled cavity + timber frame, partial insulation', 'sandstone, insulated', 'cavity wall, insulated + timber frame, insulated', 'average thermal transmittance 1.0 w/m²k', 'average thermal transmittance 0.9 w/m²k', 'average thermal transmittance 0.6 w/m²k', 'cavity wall, filled cavity', 'solid brick, insulated']
#
# Node 2:
# 	Count = 119261	Rate = 0.062443
# 	['sandstone, no insulation + cavity wall, partial insulation', 'solid brick, no insulation + cavity wall, no insulation', 'granite or whinstone, no insulation', 'sandstone, no insulation + cavity wall, no insulation', 'cavity wall, no insulation + cavity wall, insulated', 'granite or whinstone, no insulation + solid brick, no insulation', 'granite or whinstone, no insulation + cavity wall, no insulation', 'granite or whinstone, insulated + timber frame, insulated', 'sandstone, no insulation + solid brick, no insulation + cavity wall, insulated', 'granite or whinstone, no insulation + cavity wall, partial insulation + solid brick, no insulation', 'solid brick, no insulation + timber frame, insulated', 'sandstone, no insulation + cavity wall, partial insulation + cavity wall, insulated', 'system built, no insulation + solid brick, partial insulation', 'sandstone, no insulation + cavity wall, no insulation + timber frame, no insulation', 'granite or whinstone, partial insulation + cavity wall, partial insulation', 'solid brick, no insulation + solid brick, partial insulation', 'system built, no insulation + cavity wall, no insulation', 'solid brick, no insulation + granite or whinstone, no insulation', 'system built, no insulation + cavity wall, insulated', 'average thermal transmittance 2.0 w/m²k', 'timber frame, partial insulation + cavity wall, partial insulation', 'solid brick, no insulation + sandstone, no insulation', 'cavity wall, no insulation + system built, no insulation', 'timber frame, insulated + cavity wall, filled cavity', 'sandstone, no insulation + cavity wall, no insulation + cavity wall, filled cavity', 'granite or whinstone, no insulation + timber frame, no insulation', 'sandstone, no insulation + sandstone, insulated', 'cavity wall, no insulation + granite or whinstone, no insulation', 'sandstone, no insulation + solid brick, partial insulation', 'cavity wall, filled cavity + cavity wall, no insulation', 'cavity wall, insulated + granite or whinstone, insulated', 'cavity wall, partial insulation + solid brick, partial insulation', 'granite or whinstone, no insulation + solid brick, partial insulation', 'granite or whinstone, no insulation + cavity wall, partial insulation + cavity wall, insulated', 'sandstone, no insulation + cavity wall, filled cavity + timber frame, insulated', 'timber frame, insulated + granite or whinstone, insulated', 'granite or whinstone, no insulation + granite or whinstone, insulated + cavity wall, filled cavity', 'cavity wall, filled cavity + solid brick, no insulation', 'granite or whinstone, no insulation + granite or whinstone, insulated', 'sandstone, no insulation + solid brick, no insulation + solid brick, insulated', 'granite or whinstone, no insulation + solid brick, no insulation + timber frame, partial insulation', 'cavity wall, partial insulation + timber frame, insulated', 'granite or whinstone, no insulation + solid brick, no insulation + cavity wall, insulated + cavity wall, no insulation', 'sandstone, no insulation + cavity wall, insulated + cavity wall, no insulation', 'system built, no insulation + cavity wall, partial insulation', 'granite or whinstone, insulated + cavity wall, filled cavity', 'cavity wall, no insulation + cavity wall, partial insulation', 'solid brick, no insulation + timber frame, no insulation', 'granite or whinstone, no insulation + timber frame, insulated', 'timber frame, no insulation + cavity wall, no insulation', 'cavity wall, no insulation + cavity wall, partial insulation + cavity wall, insulated', 'granite or whinstone, no insulation + solid brick, insulated + cavity wall, filled cavity + cavity wall, insulated', 'cavity wall, filled cavity + timber frame, no insulation', 'timber frame, no insulation + granite or whinstone, no insulation', 'granite or whinstone, no insulation + timber frame, partial insulation', 'cavity wall, no insulation + timber frame, insulated', 'sandstone, no insulation + solid brick, no insulation + cavity wall, n ...
#
# Node 3:
# 	Count = 58929	Rate = 0.891530
# 	['timber frame, insulated', 'cavity wall, filled cavity and external insulation', 'cavity wall, filled cavity and internal insulation', 'average thermal transmittance 0.8 w/m²k', 'cavity wall, insulated', 'average thermal transmittance 0.5 w/m²k', 'system built, filled cavity', 'system built, insulated', 'average thermal transmittance 0.4 w/m²k']
#
# Node 4:
# 	Count = 12658	Rate = 0.290883
# 	['average thermal transmittance 1.4 w/m²k', 'cavity wall, no insulation + cavity wall, filled cavity', 'granite or whinstone, no insulation + cavity wall, insulated + granite or whinstone, insulated', 'average thermal transmittance 2.6 w/m²k', 'solid brick, partial insulation', 'cavity wall, partial insulation', 'average thermal transmittance 2.4 w/m²k', 'average thermal transmittance 2.2 w/m²k', 'sandstone or limestone, partial insulation', 'cavity wall, partial insulation + cavity wall, insulated', 'park home wall, as built', 'granite or whinstone, partial insulation', 'cob, as built', 'system built, no insulation', 'cavity wall,', 'average thermal transmittance 0.7 w/m²k', 'sandstone, partial insulation', 'cavity wall, filled cavity insulation', 'average thermal transmittance 1.5 w/m²k', 'average thermal transmittance 1.7 w/m²k', 'granite or whinstone, no insulation + solid brick, no insulation + cavity wall, insulated', 'solid brick, filled cavity']
#
# Node 5:
# 	Count = 36846	Rate = 0.994518
# 	['average thermal transmittance 0.0 w/m²k', 'average thermal transmittance nan w/m²k', 'cavity wall, partial insulation + system built, partial insulation', 'average thermal transmittance 0.1 w/m²k', 'cavity wall, insulated no insulation', 'cob, filled cavity', 'cob, insulated', 'timber frame, insulated + solid brick, insulated', 'cavity wall, insulated + system built, insulated', 'solid brick, insulated + cavity wall, insulated', 'average thermal transmittance 2.5 w/m²k', 'cavity wall, insulated + solid brick, insulated', 'average thermal transmittance 0.2 w/m²k', 'average thermal transmittance 0.3 w/m²k']
#
# Node 6:
# 	Count = 72	Rate = 1.000000
# 	['average thermal transmittance 0.0 w/m²k', 'average thermal transmittance nan w/m²k', 'cavity wall, partial insulation + system built, partial insulation']
#
# Node 7:
# 	Count = 334	Rate = 1.000000
# 	['average thermal transmittance 0.1 w/m²k']
#
# Node 8:
# 	Count = 17664	Rate = 0.998075
# 	['average thermal transmittance 0.2 w/m²k']
#
# Node 9:
# 	Count = 1	Rate = 1.000000
# 	['cavity wall, insulated no insulation']
#
# Node 10:
# 	Count = 1	Rate = 1.000000
# 	['cob, filled cavity']
#
# Node 11:
# 	Count = 18768	Rate = 0.991049
# 	['average thermal transmittance 0.3 w/m²k']
#
# Node 12:
# 	Count = 1	Rate = 1.000000
# 	['cob, insulated']
#
# Node 13:
# 	Count = 1	Rate = 1.000000
# 	['timber frame, insulated + solid brick, insulated']
#
# Node 14:
# 	Count = 1	Rate = 1.000000
# 	['cavity wall, insulated + system built, insulated']
#
# Node 15:
# 	Count = 1	Rate = 1.000000
# 	['solid brick, insulated + cavity wall, insulated']
#
# Node 16:
# 	Count = 1	Rate = 1.000000
# 	['average thermal transmittance 2.5 w/m²k']
#
# Node 17:
# 	Count = 1	Rate = 1.000000
# 	['cavity wall, insulated + solid brick, insulated']
#
#
#
# Variable: WALLS_ENERGY_EFF
# p-value: 0.000000
# Chi2: 174883.464798
#
# Node 1:
# 	Count = 12591	Rate = 0.493607
# 	['<missing>', 'Average']
#
# Node 2:
# 	Count = 113652	Rate = 0.833395
# 	['Good']
#
# Node 3:
# 	Count = 32716	Rate = 0.993367
# 	['Very Good']
#
# Node 4:
# 	Count = 125875	Rate = 0.071388
# 	['Very Poor', 'Poor']
#
#
#
# Variable: WALLS_ENV_EFF
# p-value: 0.000000
# Chi2: 174883.464798
#
# Node 1:
# 	Count = 12591	Rate = 0.493607
# 	['<missing>', 'Average']
#
# Node 2:
# 	Count = 113652	Rate = 0.833395
# 	['Good']
#
# Node 3:
# 	Count = 32716	Rate = 0.993367
# 	['Very Good']
#
# Node 4:
# 	Count = 125875	Rate = 0.071388
# 	['Very Poor', 'Poor']
#
#
#
# Variable: ROOF_DESCRIPTION
# p-value: 0.000000
# Chi2: 120660.324669
#
# Node 1:
# 	Count = 107081	Rate = 0.559268
# 	['<missing>', 'Pitched, 350mm loft insulation', 'Pitched, 250mm loft insulation + Pitched, 0mm loft insulation', 'average thermal transmittance 0.8 w/m²k', 'average thermal transmittance 0.6 w/m²k', 'Pitched, 400+mm loft insulation', 'Pitched, 300+mm loft insulation', 'Roof room(s), insulated', 'Pitched', 'Pitched, 250mm loft insulation', 'Flat, insulated', 'Pitched, 200mm loft insulation', 'Pitched, 300mm loft insulation', 'Pitched, 75mm loft insulation + Flat, insulated', 'Pitched, 150mm loft insulation', 'Pitched, 250mm loft insulation + Pitched, insulated', 'Pitched, 250mm loft insulation + Flat, insulated', 'Pitched, 200mm loft insulation + Pitched, 100mm loft insulation', 'Pitched, limited insulation + Roof room(s), insulated', 'Pitched. Loft insulation at rafters', 'Pitched, 270mm loft insulation', 'Pitched, 400mm loft insulation']
#
# Node 2:
# 	Count = 43340	Rate = 0.009437
# 	['Pitched, 200mm loft insulation + Roof room(s), limited insulation', 'Pitched, no insulation + Pitched, 0mm loft insulation + Roof room(s), insulated', 'Pitched, 300mm loft insulation + Flat, limited insulation + Roof room(s), limited insulation', 'Pitched, 150mm loft insulation + Pitched, 0mm loft insulation', 'Pitched, 100mm loft insulation + Pitched, 250mm loft insulation', 'Pitched, 150mm loft insulation + Roof room(s), limited insulation', 'Pitched, 100mm loft insulation + Pitched, limited insulation + Pitched, insulated', 'Pitched, no insulation + Pitched, insulated + Roof room(s), no insulation', 'average thermal transmittance 1.9 w/m²k', 'Pitched, 100mm loft insulation + Pitched, no insulation + Pitched, limited insulation', 'Pitched, 250mm loft insulation + Flat, insulated + Roof room(s), limited insulation', 'Pitched, 100mm loft insulation + Pitched, 75mm loft insulation', 'Flat, limited insulation + Flat, insulated', 'Pitched, 300mm loft insulation + Roof room(s), limited insulation', 'Pitched, 0mm loft insulation + Pitched, 200mm loft insulation', 'Pitched, limited insulation + Roof room(s), limited insulation', 'Thatched', 'Pitched, 150mm loft insulation + Pitched, 0mm loft insulation + Pitched, insulated', 'Pitched, 75mm loft insulation + Roof room(s), no insulation', 'Pitched, no insulation + Pitched, 25mm loft insulation', 'Pitched, 150mm loft insulation + Pitched, insulated + Pitched, 0mm loft insulation + Roof room(s), limited insulation', 'Pitched, 100mm loft insulation + Pitched, no insulation + Flat, no insulation', 'Pitched, 300mm loft insulation + Roof room(s), no insulation', 'Pitched, no insulation + Pitched, 75mm loft insulation', 'Pitched, no insulation + Pitched, insulated + Roof room(s), insulated', 'Pitched, no insulation + Pitched, limited insulation', 'Pitched, 12mm loft insulation + Pitched, 25mm loft insulation', 'Pitched, 50mm loft insulation + Flat, limited insulation', 'Pitched, 100mm loft insulation + Pitched, insulated + Pitched, 300mm loft insulation', 'Pitched, limited insulation + Pitched, 150mm loft insulation', 'Pitched, no insulation + Flat, limited insulation + Roof room(s), insulated', 'Pitched, 100mm loft insulation + Flat, no insulation + Pitched, 150mm loft insulation', 'Pitched, 75mm loft insulation + Flat, insulated + Roof room(s), limited insulation', 'Pitched, 100mm loft insulation + Flat, no insulation', 'Pitched, no insulation + Pitched, insulated + Pitched, 200mm loft insulation', '(other premises above) + Flat, no insulation + Pitched, 150mm loft insulation', 'Pitched, 150mm loft insulation + Flat, insulated + Roof room(s), limited insulation', 'Pitched, 50mm loft insulation + Pitched, no insulation', 'Pitched, no insulation + (other premises above)', 'Pitched, no insulation + Pitched, 50mm loft insulation', 'Pitched, 300mm loft insulation + Pitched, no insulation', 'Pitched, 50mm loft insulation + Flat, insulated', 'Pitched, 300mm loft insulation + Pitched, 100mm loft insulation', 'Pitched, insulated + Flat, insulated + Roof room(s), no insulation', 'Pitched, 200mm loft insulation + Pitched, insulated + Roof room(s), no insulation', 'Pitched, 250mm loft insulation + Pitched, 200mm loft insulation', 'Pitched, 100mm loft insulation + Pitched, 50mm loft insulation', 'Pitched, 75mm loft insulation + Pitched, no insulation', 'Pitched, 75mm loft insulation + (other premises above) + Pitched, limited insulation', 'Pitched, 0mm loft insulation + Pitched, 100mm loft insulation', '(other premises above) + Pitched, no insulation', 'Pitched, 200mm loft insulation + Pitched, 0mm loft insulation', 'Pitched, 150mm loft insulation + Flat, no insulation', 'Roof room(s), thatched', 'Pitched, no insulation + Flat, insulated + Roof room(s), insulated', 'Pitched, no insulation + Pitched, limited insulation + Roof room(s), limited insulation', 'Pitched, no insulation + Pitched, 75mm loft insulation + Roof room(s), limited insulation', 'Always, limited insulation', 'Pitched, 150mm loft ins ...
#
# Node 3:
# 	Count = 217	Rate = 0.000000
# 	['Pitched, 200mm loft insulation + Roof room(s), limited insulation', 'Pitched, no insulation + Pitched, 0mm loft insulation + Roof room(s), insulated', 'Pitched, 300mm loft insulation + Flat, limited insulation + Roof room(s), limited insulation', 'Pitched, 150mm loft insulation + Pitched, 0mm loft insulation', 'Pitched, 100mm loft insulation + Pitched, 250mm loft insulation', 'Pitched, 150mm loft insulation + Roof room(s), limited insulation', 'Pitched, 100mm loft insulation + Pitched, limited insulation + Pitched, insulated', 'Pitched, no insulation + Pitched, insulated + Roof room(s), no insulation', 'average thermal transmittance 1.9 w/m²k', 'Pitched, 100mm loft insulation + Pitched, no insulation + Pitched, limited insulation', 'Pitched, 250mm loft insulation + Flat, insulated + Roof room(s), limited insulation', 'Pitched, 100mm loft insulation + Pitched, 75mm loft insulation', 'Flat, limited insulation + Flat, insulated', 'Pitched, 300mm loft insulation + Roof room(s), limited insulation', 'Pitched, 0mm loft insulation + Pitched, 200mm loft insulation', 'Pitched, limited insulation + Roof room(s), limited insulation', 'Thatched', 'Pitched, 150mm loft insulation + Pitched, 0mm loft insulation + Pitched, insulated', 'Pitched, 75mm loft insulation + Roof room(s), no insulation', 'Pitched, no insulation + Pitched, 25mm loft insulation', 'Pitched, 150mm loft insulation + Pitched, insulated + Pitched, 0mm loft insulation + Roof room(s), limited insulation', 'Pitched, 100mm loft insulation + Pitched, no insulation + Flat, no insulation', 'Pitched, 300mm loft insulation + Roof room(s), no insulation', 'Pitched, no insulation + Pitched, 75mm loft insulation', 'Pitched, no insulation + Pitched, insulated + Roof room(s), insulated', 'Pitched, no insulation + Pitched, limited insulation', 'Pitched, 12mm loft insulation + Pitched, 25mm loft insulation', 'Pitched, 50mm loft insulation + Flat, limited insulation', 'Pitched, 100mm loft insulation + Pitched, insulated + Pitched, 300mm loft insulation', 'Pitched, limited insulation + Pitched, 150mm loft insulation', 'Pitched, no insulation + Flat, limited insulation + Roof room(s), insulated', 'Pitched, 100mm loft insulation + Flat, no insulation + Pitched, 150mm loft insulation', 'Pitched, 75mm loft insulation + Flat, insulated + Roof room(s), limited insulation', 'Pitched, 100mm loft insulation + Flat, no insulation', 'Pitched, no insulation + Pitched, insulated + Pitched, 200mm loft insulation', '(other premises above) + Flat, no insulation + Pitched, 150mm loft insulation', 'Pitched, 150mm loft insulation + Flat, insulated + Roof room(s), limited insulation', 'Pitched, 50mm loft insulation + Pitched, no insulation', 'Pitched, no insulation + (other premises above)', 'Pitched, no insulation + Pitched, 50mm loft insulation', 'Pitched, 300mm loft insulation + Pitched, no insulation', 'Pitched, 50mm loft insulation + Flat, insulated', 'Pitched, 300mm loft insulation + Pitched, 100mm loft insulation', 'Pitched, insulated + Flat, insulated + Roof room(s), no insulation', 'Pitched, 200mm loft insulation + Pitched, insulated + Roof room(s), no insulation', 'Pitched, 250mm loft insulation + Pitched, 200mm loft insulation', 'Pitched, 100mm loft insulation + Pitched, 50mm loft insulation', 'Pitched, 75mm loft insulation + Pitched, no insulation', 'Pitched, 75mm loft insulation + (other premises above) + Pitched, limited insulation', 'Pitched, 0mm loft insulation + Pitched, 100mm loft insulation', '(other premises above) + Pitched, no insulation', 'Pitched, 200mm loft insulation + Pitched, 0mm loft insulation', 'Pitched, 150mm loft insulation + Flat, no insulation', 'Roof room(s), thatched', 'Pitched, no insulation + Flat, insulated + Roof room(s), insulated', 'Pitched, no insulation + Pitched, limited insulation + Roof room(s), limited insulation', 'Pitched, no insulation + Pitched, 75mm loft insulation + Roof room(s), limited insulation', 'Always, limited insulation', 'Pitched, 150mm loft ins ...
#
# Node 4:
# 	Count = 32	Rate = 0.000000
# 	['Pitched, 100mm loft insulation + Pitched, no insulation']
#
# Node 5:
# 	Count = 5	Rate = 0.000000
# 	['Pitched, 75mm loft insulation + Pitched, 150mm loft insulation']
#
# Node 6:
# 	Count = 6	Rate = 0.000000
# 	['Pitched, 50mm loft insulation + Flat, no insulation']
#
# Node 7:
# 	Count = 2500	Rate = 0.003600
# 	['Roof room(s), no insulation']
#
# Node 8:
# 	Count = 3	Rate = 0.000000
# 	['Pitched, 300mm loft insulation + Pitched, limited insulation']
#
# Node 9:
# 	Count = 1	Rate = 0.000000
# 	['average thermal transmittance 1.4 w/m²k']
#
# Node 10:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, no insulation + Pitched, insulated + Roof room(s), limited insulation']
#
# Node 11:
# 	Count = 2	Rate = 0.000000
# 	['Pitched, no insulation + Pitched, 75mm loft insulation + Roof room(s), no insulation']
#
# Node 12:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 0mm loft insulation + Pitched, no insulation + Flat, limited insulation']
#
# Node 13:
# 	Count = 2	Rate = 0.000000
# 	['Pitched, 100mm loft insulation + Flat, insulated + Roof room(s), no insulation']
#
# Node 14:
# 	Count = 3	Rate = 0.000000
# 	['Pitched, 250mm loft insulation + Flat, no insulation']
#
# Node 15:
# 	Count = 1416	Rate = 0.021186
# 	['Pitched, 12mm loft insulation']
#
# Node 16:
# 	Count = 3	Rate = 0.000000
# 	['Pitched, 25mm loft insulation + Pitched, 100mm loft insulation']
#
# Node 17:
# 	Count = 4	Rate = 0.000000
# 	['Pitched, 12mm loft insulation + Flat, no insulation']
#
# Node 18:
# 	Count = 2	Rate = 0.000000
# 	['Pitched, 12mm loft insulation + Roof room(s), limited insulation']
#
# Node 19:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 0mm loft insulation + Pitched, 25mm loft insulation']
#
# Node 20:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 75mm loft insulation + Pitched, no insulation + Pitched, limited insulation']
#
# Node 21:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 75mm loft insulation + Pitched, no insulation + Pitched, insulated']
#
# Node 22:
# 	Count = 35	Rate = 0.000000
# 	['Pitched, none loft insulation']
#
# Node 23:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 250mm loft insulation + Pitched, limited insulation + Pitched, insulated']
#
# Node 24:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 300mm loft insulation + Pitched, 250mm loft insulation']
#
# Node 25:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 75mm loft insulation + Pitched, insulated + Flat, insulated']
#
# Node 26:
# 	Count = 8	Rate = 0.000000
# 	['Pitched, 75mm loft insulation + Pitched, insulated']
#
# Node 27:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 75mm loft insulation + Pitched, 12mm loft insulation + Pitched, insulated']
#
# Node 28:
# 	Count = 15	Rate = 0.000000
# 	['Pitched, 0mm loft insulation + Flat, limited insulation']
#
# Node 29:
# 	Count = 1	Rate = 0.000000
# 	['(other premises above) + Pitched, 300mm loft insulation']
#
# Node 30:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, limited insulation + Pitched, insulated']
#
# Node 31:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 0mm loft insulation + Pitched, no insulation + Pitched, 25mm loft insulation']
#
# Node 32:
# 	Count = 2	Rate = 0.000000
# 	['Pitched, 25mm loft insulation + Roof room(s), insulated']
#
# Node 33:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 100mm loft insulation + Pitched, no insulation + Roof room(s), insulated']
#
# Node 34:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, limited insulation + Roof room(s), no insulation + Roof room(s), limited insulation']
#
# Node 35:
# 	Count = 12	Rate = 0.000000
# 	['Pitched, 0mm loft insulation + Roof room(s), no insulation']
#
# Node 36:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 150mm loft insulation + Pitched, no insulation + Pitched, limited insulation']
#
# Node 37:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 150mm loft insulation + Pitched, 100mm loft insulation']
#
# Node 38:
# 	Count = 2	Rate = 0.000000
# 	['Pitched, 50mm loft insulation + Roof room(s), limited insulation']
#
# Node 39:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, no insulation + Pitched, 200mm loft insulation + Roof room(s), limited insulation']
#
# Node 40:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 75mm loft insulation + Pitched, no insulation + Roof room(s), no insulation']
#
# Node 41:
# 	Count = 1	Rate = 0.000000
# 	['Roof room(s), no insulation + Roof room(s), limited insulation + Roof room(s), insulated']
#
# Node 42:
# 	Count = 3	Rate = 0.000000
# 	['Pitched, 25mm loft insulation + Pitched, insulated']
#
# Node 43:
# 	Count = 7	Rate = 0.000000
# 	['Pitched, 150mm loft insulation + Flat, limited insulation']
#
# Node 44:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 25mm loft insulation + Flat, no insulation']
#
# Node 45:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 150mm loft insulation + Pitched, no insulation + Flat, no insulation']
#
# Node 46:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 75mm loft insulation + Pitched, limited insulation + Pitched, 200mm loft insulation']
#
# Node 47:
# 	Count = 6	Rate = 0.000000
# 	['Pitched, 25mm loft insulation + Flat, limited insulation']
#
# Node 48:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 100mm loft insulation + Pitched, 75mm loft insulation + Pitched, limited insulation']
#
# Node 49:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, no insulation + Flat, limited insulation + Roof room(s), no insulation']
#
# Node 50:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 50mm loft insulation + Pitched, no insulation + Pitched, limited insulation']
#
# Node 51:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 25mm loft insulation + Roof room(s), limited insulation']
#
# Node 52:
# 	Count = 2	Rate = 0.000000
# 	['Pitched, 200mm loft insulation + Pitched, no insulation + Pitched, insulated']
#
# Node 53:
# 	Count = 2	Rate = 0.000000
# 	['Pitched, no insulation + Pitched, 50mm loft insulation + Roof room(s), no insulation']
#
# Node 54:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 50mm loft insulation + Pitched, no insulation + Flat, limited insulation']
#
# Node 55:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 50mm loft insulation + Flat, insulated + Roof room(s), no insulation']
#
# Node 56:
# 	Count = 2	Rate = 0.000000
# 	['Pitched, 12mm loft insulation + Flat, limited insulation']
#
# Node 57:
# 	Count = 6	Rate = 0.000000
# 	['Pitched, 150mm loft insulation + Roof room(s), no insulation']
#
# Node 58:
# 	Count = 4	Rate = 0.000000
# 	['Pitched, 200mm loft insulation + Pitched, insulated']
#
# Node 59:
# 	Count = 18	Rate = 0.000000
# 	['Pitched, 75mm loft insulation + Flat, limited insulation']
#
# Node 60:
# 	Count = 2	Rate = 0.000000
# 	['Pitched,  loft insulation']
#
# Node 61:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, no insulation + Pitched, insulated + Pitched, limited insulation + Roof room(s), insulated']
#
# Node 62:
# 	Count = 5	Rate = 0.000000
# 	['Pitched, 100mm loft insulation + Pitched, 0mm loft insulation']
#
# Node 63:
# 	Count = 1397	Rate = 0.014316
# 	['Flat, no insulation']
#
# Node 64:
# 	Count = 4	Rate = 0.000000
# 	['Pitched, no insulation + Pitched, 150mm loft insulation + Roof room(s), insulated']
#
# Node 65:
# 	Count = 5	Rate = 0.000000
# 	['Pitched, 100mm loft insulation + Pitched, 150mm loft insulation']
#
# Node 66:
# 	Count = 11	Rate = 0.000000
# 	['Pitched, no insulation + Pitched, insulated']
#
# Node 67:
# 	Count = 309	Rate = 0.006472
# 	['Pitched, 0mm loft insulation']
#
# Node 68:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 25mm loft insulation + Pitched, no insulation + Roof room(s), no insulation']
#
# Node 69:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 75mm loft insulation + Pitched, insulated + Roof room(s), insulated']
#
# Node 70:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 100mm loft insulation + Pitched, 150mm loft insulation + Flat, insulated']
#
# Node 71:
# 	Count = 3	Rate = 0.000000
# 	['Pitched, 250mm loft insulation + Roof room(s), limited insulation']
#
# Node 72:
# 	Count = 46	Rate = 0.000000
# 	['Pitched, no insulation + Roof room(s), insulated']
#
# Node 73:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, no insulation + Pitched, limited insulation + Flat, insulated']
#
# Node 74:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 100mm loft insulation + Pitched, no insulation + Roof room(s), limited insulation']
#
# Node 75:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 150mm loft insulation + Flat, insulated + Roof room(s), no insulation']
#
# Node 76:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 75mm loft insulation + Pitched, 50mm loft insulation']
#
# Node 77:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, no insulation + Pitched, 0mm loft insulation']
#
# Node 78:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, no insulation + Pitched, limited insulation + Roof room(s), insulated']
#
# Node 79:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 200mm loft insulation + Pitched, insulated + Roof room(s), insulated']
#
# Node 80:
# 	Count = 3	Rate = 0.000000
# 	['Pitched, 75mm loft insulation + Pitched, 100mm loft insulation']
#
# Node 81:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 100mm loft insulation + Flat, insulated + Roof room(s), limited insulation']
#
# Node 82:
# 	Count = 3	Rate = 0.000000
# 	['Pitched, no insulation + Pitched, 150mm loft insulation']
#
# Node 83:
# 	Count = 2	Rate = 0.000000
# 	['Pitched, 25mm loft insulation + Pitched, limited insulation']
#
# Node 84:
# 	Count = 2	Rate = 0.000000
# 	['Flat, insulated + Roof room(s), no insulation']
#
# Node 85:
# 	Count = 9	Rate = 0.000000
# 	['Pitched, 150mm loft insulation + Pitched, limited insulation']
#
# Node 86:
# 	Count = 6	Rate = 0.000000
# 	['Flat, no insulation + Roof room(s), no insulation']
#
# Node 87:
# 	Count = 2	Rate = 0.000000
# 	['Pitched, no insulation + Pitched, 100mm loft insulation']
#
# Node 88:
# 	Count = 1	Rate = 0.000000
# 	['(other premises above) + Pitched, limited insulation']
#
# Node 89:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, no insulation + Flat, insulated + Roof room(s), no insulation']
#
# Node 90:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 100mm loft insulation + Pitched, no insulation + Roof room(s), no insulation']
#
# Node 91:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 250mm loft insulation + Pitched, 100mm loft insulation']
#
# Node 92:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, no insulation + Pitched, 75mm loft insulation + Pitched, insulated']
#
# Node 93:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 200mm loft insulation + Pitched, 250mm loft insulation + Roof room(s), insulated']
#
# Node 94:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 100mm loft insulation + Flat, insulated + Flat, limited insulation']
#
# Node 95:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 12mm loft insulation + Pitched, limited insulation']
#
# Node 96:
# 	Count = 1	Rate = 0.000000
# 	['Flat, insulated + Roof room(s), limited insulation']
#
# Node 97:
# 	Count = 2	Rate = 0.000000
# 	['average thermal transmittance 1.2 w/m²k']
#
# Node 98:
# 	Count = 1	Rate = 0.000000
# 	['Flat, limited insulation + Pitched, limited insulation']
#
# Node 99:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, no insulation + Pitched, 75mm loft insulation + Roof room(s), insulated']
#
# Node 100:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 75mm loft insulation + Pitched, 0mm loft insulation + Pitched, no insulation']
#
# Node 101:
# 	Count = 4	Rate = 0.000000
# 	['Pitched, 250mm loft insulation + Roof room(s), no insulation']
#
# Node 102:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 200mm loft insulation + Pitched, no insulation + Pitched, limited insulation']
#
# Node 103:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 250mm loft insulation + Pitched, 300mm loft insulation']
#
# Node 104:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 100mm loft insulation + Pitched, 0mm loft insulation + Roof room(s), insulated']
#
# Node 105:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 300mm loft insulation + Pitched, no insulation + Flat, insulated']
#
# Node 106:
# 	Count = 8	Rate = 0.000000
# 	['Pitched, no insulation + Flat, no insulation']
#
# Node 107:
# 	Count = 2	Rate = 0.000000
# 	['Pitched, limited insulation + Flat, insulated']
#
# Node 108:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 200mm loft insulation + Roof room(s), no insulation']
#
# Node 109:
# 	Count = 2	Rate = 0.000000
# 	['Pitched, 200mm loft insulation + Pitched, limited insulation']
#
# Node 110:
# 	Count = 3	Rate = 0.000000
# 	['Pitched, 50mm loft insulation + Pitched, 100mm loft insulation']
#
# Node 111:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 0mm loft insulation + Pitched, insulated + Roof room(s), insulated']
#
# Node 112:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 300mm loft insulation + Pitched, 75mm loft insulation']
#
# Node 113:
# 	Count = 3	Rate = 0.000000
# 	['Pitched, 50mm loft insulation + Roof room(s), no insulation']
#
# Node 114:
# 	Count = 1	Rate = 0.000000
# 	['average thermal transmittance 1.8 w/m²k']
#
# Node 115:
# 	Count = 2	Rate = 0.000000
# 	['Pitched, 200mm loft insulation + Pitched, 150mm loft insulation']
#
# Node 116:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 150mm loft insulation + Pitched, 0mm loft insulation + Flat, no insulation']
#
# Node 117:
# 	Count = 2	Rate = 0.000000
# 	['Pitched, insulated + Roof room(s), limited insulation']
#
# Node 118:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, no insulation + Flat, no insulation + Pitched, 0mm loft insulation']
#
# Node 119:
# 	Count = 5	Rate = 0.000000
# 	['Pitched, 250mm loft insulation + Flat, limited insulation']
#
# Node 120:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 75mm loft insulation + Flat, insulated + Flat, no insulation']
#
# Node 121:
# 	Count = 3	Rate = 0.000000
# 	['Roof room(s), no insulation + Roof room(s), limited insulation']
#
# Node 122:
# 	Count = 2	Rate = 0.000000
# 	['Pitched, 100mm loft insulation + Pitched, limited insulation + Flat, limited insulation']
#
# Node 123:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 50mm loft insulation + Roof room(s), insulated']
#
# Node 124:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, no insulation + Pitched, 75mm loft insulation + Flat, insulated']
#
# Node 125:
# 	Count = 1	Rate = 0.000000
# 	['Flat, no insulation + Flat, limited insulation']
#
# Node 126:
# 	Count = 1	Rate = 0.000000
# 	['Pitched + Roof room(s), insulated']
#
# Node 127:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 250mm loft insulation + (other premises above) + Pitched, insulated']
#
# Node 128:
# 	Count = 4	Rate = 0.000000
# 	['Pitched, 0mm loft insulation + Flat, insulated']
#
# Node 129:
# 	Count = 32	Rate = 0.000000
# 	['Pitched,mm loft insulation']
#
# Node 130:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 100mm loft insulation + Roof room(s), no insulation + Roof room(s), insulated']
#
# Node 131:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 200mm loft insulation + Pitched, 100mm loft insulation + Pitched, limited insulation']
#
# Node 132:
# 	Count = 4	Rate = 0.000000
# 	['average thermal transmittance 0.5 w/m²k']
#
# Node 133:
# 	Count = 3	Rate = 0.000000
# 	['Pitched, 50mm loft insulation + Pitched, 0mm loft insulation']
#
# Node 134:
# 	Count = 9	Rate = 0.000000
# 	['Pitched, 0mm loft insulation + Pitched, insulated']
#
# Node 135:
# 	Count = 14	Rate = 0.000000
# 	['Pitched, 100mm loft insulation + Pitched, limited insulation']
#
# Node 136:
# 	Count = 6	Rate = 0.000000
# 	['Pitched, 300mm loft insulation + Flat, insulated']
#
# Node 137:
# 	Count = 2	Rate = 0.000000
# 	['Pitched, 150mm loft insulation + Pitched, 75mm loft insulation']
#
# Node 138:
# 	Count = 1	Rate = 0.000000
# 	['Pitched + Pitched, no insulation']
#
# Node 139:
# 	Count = 10	Rate = 0.000000
# 	['Pitched, no insulation + Roof room(s), limited insulation']
#
# Node 140:
# 	Count = 2	Rate = 0.000000
# 	['Pitched, 12mm loft insulation + Pitched, no insulation']
#
# Node 141:
# 	Count = 4	Rate = 0.000000
# 	['Pitched, 250mm loft insulation + Pitched, no insulation']
#
# Node 142:
# 	Count = 1	Rate = 0.000000
# 	['Roof room(s), no insulation + Roof room(s), insulated']
#
# Node 143:
# ...
#
# Node 182:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 100mm loft insulation + Pitched, limited insulation + Roof room(s), insulated']
#
# Node 183:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, no insulation + Flat, insulated + Roof room(s), limited insulation']
#
# Node 184:
# 	Count = 3	Rate = 0.000000
# 	['Pitched, no insulation + Flat, no insulation + Roof room(s), limited insulation']
#
# Node 185:
# 	Count = 3	Rate = 0.000000
# 	['Pitched, 25mm loft insulation + Flat, insulated']
#
# Node 186:
# 	Count = 6	Rate = 0.000000
# 	['Pitched, no insulation + Flat, insulated']
#
# Node 187:
# 	Count = 5	Rate = 0.000000
# 	['Pitched, 0mm loft insulation + Pitched, limited insulation']
#
# Node 188:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 75mm loft insulation + Flat, limited insulation + Roof room(s), limited insulation']
#
# Node 189:
# 	Count = 2	Rate = 0.000000
# 	['Pitched, limited insulation + Roof room(s), no insulation']
#
# Node 190:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, 25mm loft insulation + Flat, insulated + Roof room(s), limited insulation']
#
# Node 191:
# 	Count = 1	Rate = 0.000000
# 	['Pitched, no insulation + Pitched, 50mm loft insulation + Flat, limited insulation + Roof room(s), insulated']
#
# Node 192:
# 	Count = 7	Rate = 0.000000
# 	['Pitched, 75mm loft insulation + Flat, no insulation']
#
# Node 193:
# 	Count = 18	Rate = 0.000000
# 	['Pitched, no insulation + Flat, limited insulation']
#
# Node 194:
# 	Count = 34374	Rate = 0.992843
# 	['(other premises above) + Pitched, 250mm loft insulation', 'Pitched, 50mm loft insulation + Pitched, 250mm loft insulation', 'Pitched, 250mm loft insulation + Pitched, 150mm loft insulation', 'Pitched, 200mm loft insulation + Flat, insulated + Roof room(s), insulated', 'Pitched + Roof room(s), limited insulation', 'Pitched, 250mm loft insulation + Flat, insulated + Roof room(s), insulated', 'Pitched, 150mm loft insulation + Pitched, 200mm loft insulation', 'Pitched, 150mm loft insulation + Pitched, 300mm loft insulation', 'average thermal transmittance 1.0 w/m²k', '(other premises above) + Pitched, 100mm loft insulation', '(other premises above) + Flat, limited insulation', 'Pitched, 200mm loft insulation + Roof room(s), insulated', 'average thermal transmittance 0.1 w/m²k', 'average thermal transmittance 0.2 w/m²k', 'average thermal transmittance 0.0 w/m²k']
#
# Node 195:
# 	Count = 28922	Rate = 0.272664
# 	['average thermal transmittance 0.7 w/m²k', 'Pitched, 300mm loft insulation + Pitched, insulated', 'Pitched, 200mm loft insulation + Flat, insulated', 'Pitched, 200mm loft insulation + Pitched, 250mm loft insulation', 'Pitched, 150mm loft insulation + Roof room(s), insulated', 'Pitched, loft insulation', 'average thermal transmittance 2.3 w/m²k', 'Pitched, 150mm loft insulation + Flat, insulated', 'Pitched, insulated at rafters', 'Flat', 'Pitched, 250mm loft insulation + Pitched, limited insulation', 'Pitched, 100mm loft insulation + Pitched, 200mm loft insulation', 'Pitched, 200mm loft insulation + Flat, no insulation', 'Thatched, with additional insulation', 'Pitched, 50mm loft insulation + Pitched, insulated', 'Pitched, 100mm loft insulation']
#
# Node 196:
# 	Count = 28755	Rate = 0.126830
# 	['Roof room(s), ceiling insulated', 'Flat, limited insulation', 'Pitched, 100mm loft insulation + Roof room(s), insulated', 'Pitched, 75mm loft insulation', 'Pitched, 100mm loft insulation + Roof room(s), limited insulation', 'Pitched, Unknown loft insulation', 'Pitched, 25mm loft insulation', 'Pitched, 100mm loft insulation + Flat, insulated', 'Pitched, 200mm loft insulation + Flat, limited insulation', 'Pitched, 100mm loft insulation + Pitched, insulated', 'Pitched, 50mm loft insulation', 'Pitched, 200mm loft insulation + Pitched, no insulation', 'Pitched, limited insulation']
#
# Node 197:
# 	Count = 42362	Rate = 0.860677
# 	['Pitched, 300mm loft insulation + Roof room(s), insulated', '(other premises above)', 'average thermal transmittance 0.3 w/m²k', 'average thermal transmittance 0.4 w/m²k', 'Pitched, 250mm loft insulation + Roof room(s), insulated', 'Pitched, insulated + Roof room(s), insulated', 'Pitched, insulated']
#
#
#
# Variable: ROOF_ENERGY_EFF
# p-value: 0.000000
# Chi2: 106638.422678
#
# Node 1:
# 	Count = 80319	Rate = 0.839527
# 	['<missing>', 'Very Good']
#
# Node 2:
# 	Count = 103069	Rate = 0.613637
# 	['Good']
#
# Node 3:
# 	Count = 38440	Rate = 0.243444
# 	['Average']
#
# Node 4:
# 	Count = 47060	Rate = 0.017085
# 	['Very Poor']
#
# Node 5:
# 	Count = 15946	Rate = 0.098959
# 	['Poor']
#
#
#
# Variable: ROOF_ENV_EFF
# p-value: 0.000000
# Chi2: 106638.422678
#
# Node 1:
# 	Count = 80319	Rate = 0.839527
# 	['<missing>', 'Very Good']
#
# Node 2:
# 	Count = 103069	Rate = 0.613637
# 	['Good']
#
# Node 3:
# 	Count = 38440	Rate = 0.243444
# 	['Average']
#
# Node 4:
# 	Count = 47060	Rate = 0.017085
# 	['Very Poor']
#
# Node 5:
# 	Count = 15946	Rate = 0.098959
# 	['Poor']
#
#
#
# Variable: MAINHEAT_ENERGY_EFF
# p-value: 0.000000
# Chi2: 60719.187867
#
# Node 1:
# 	Count = 28187	Rate = 0.935680
# 	['<missing>', 'Very Good']
#
# Node 2:
# 	Count = 167680	Rate = 0.590375
# 	['Good']
#
# Node 3:
# 	Count = 88967	Rate = 0.191633
# 	['Average', 'Very Poor', 'Poor']
#
#
#
# Variable: MAINHEAT_ENV_EFF
# p-value: 0.000000
# Chi2: 51657.096984
#
# Node 1:
# 	Count = 34266	Rate = 0.892459
# 	['<missing>', 'Very Good']
#
# Node 2:
# 	Count = 176550	Rate = 0.548287
# 	['Good']
#
# Node 3:
# 	Count = 35095	Rate = 0.100584
# 	['Average']
#
# Node 4:
# 	Count = 38923	Rate = 0.295609
# 	['Very Poor', 'Poor']
#
#
#
# Variable: MAINHEATCONT_DESCRIPTION
# p-value: 0.000000
# Chi2: 112541.422045
#
# Node 1:
# 	Count = 108239	Rate = 0.764715
# 	['<missing>', 'Rhaglennydd, thermostat ystafell a TRVs', 'Controls for high heat retention storage heaters', 'Celect control', 'Charging system linked to the use of community heating, programmer and TRVs', 'Flat rate charging, no stat control of room temperature', 'Programmer, TRVs and flow switch', 'Flat rate charging, programmer and at least two room thermostats', 'Flat rate charging, programmer, no room thermostat', 'Temperature zone control', 'Programmer and room thermostats', 'Programmer, room thermostat and TRVs']
#
# Node 2:
# 	Count = 27164	Rate = 0.977176
# 	['Charging system linked to use of community heating, TRVs', 'Flat rate charging, room thermostat only', 'Time and temperature zone control', 'Flat rate charging, programmer and TRVs', 'Charging system linked to use of community heating, programmer and TRVs', 'Flat rate charging, no thermostatic control', 'Flat rate charging, TRVs', 'Flat rate charging, programmer and room thermostat', 'Celect-type controls', 'Tal un gyfradd, thermostat ystafell yn unig', 'Charging system linked to use of community heating, room thermostat only', "TRV's, program & flow switch", 'Charging system linked to use of communit heating, programmer and TRVs', 'Delayed start thermostat, programmer and TRVs', 'Charging system linked to the use of community heating, prog and TRVs', '2207 Time and temperature zone control', 'Charging linked to use, programmer and TRVs', 'Rheolaeth amser a rheolaeth parthau tymheredd', "Delayed start stat & program & TRV's", 'Charging system linked to use of communit heating, room thermostat only', 'Charging system linked to use of community heating, programmer and at least two room thermostats', 'Celect controls', 'Charging system linked to use of communit heating, TRVs', 'Charging system linked to use of community heating, programmerand room thermostat', 'Flat rate charging, programmer no room thermostat', 'Flat rate charging*, programmer and TRVs', 'Flat rate charging, programmer and room stat', 'CELECT-type controls', 'Programmer and at least two room thermostats including a delayed start thermostat', 'Charging system linked to use of communit heating, programmer and room thermostat', 'Unit charging, programmer and TRVs', 'Programmer, roomstat and TRVs', 'Charging system linked to use of community heating, programmer and room thermostat', 'Flat rate charging, no thermostatic control of room temperature']
#
# Node 3:
# 	Count = 97431	Rate = 0.271813
# 	['Rhaglennydd, TRVs a falf osgoi', 'Room thermostat only', 'Programmer, TRVs and bypass', 'Programmer, no thermostat', 'TRVs and bypass', 'Programmer and at least 2 room thermostats', 'Rhaglennydd a thermostat ystafell', "Rheoli'r t?l ? llaw", 'Manual charge control', 'Programmer and room thermostat', 'Appliance thermostats']
#
# Node 4:
# 	Count = 10026	Rate = 0.535308
# 	['Programmer and appliance thermostats', 'Programmer and at least two room thermostats', 'Programmer + room thermostat + TRVs', 'Programmer, TRVs and boiler energy manager', 'Room thermostats only', 'Automatic charge control']
#
# Node 5:
# 	Count = 41974	Rate = 0.029804
# 	['Programmer, no room thermostat', 'No time or thermostatic control of room temp', 'Rhaglennydd, dim thermostat ystafell', 'Programmer + room thermostat', 'Programmer + TRVs + bypass', 'Rheoli?r tal a llaw', 'Not relevant (supplies DHW only)', 'TRVs a falf osgoi', 'Dim rheolaeth amser na rheolaeth thermostatig ar dymheredd yr ystafell', 'Thermostat ystafell yn unig', 'Dim', 'Dim rheolaeth thermostatig ar dymheredd yr ystafell', "Rheoli'r tâl â llaw", 'None', 'No thermostatic control of room temperature', 'No time or thermostatic control of room temperature']
#
#
#
# Variable: MAINHEATC_ENERGY_EFF
# p-value: 0.000000
# Chi2: 77894.222317
#
# Node 1:
# 	Count = 97068	Rate = 0.744303
# 	['<missing>', 'Good']
#
# Node 2:
# 	Count = 87452	Rate = 0.418149
# 	['Average']
#
# Node 3:
# 	Count = 18446	Rate = 0.981351
# 	['Very Good']
#
# Node 4:
# 	Count = 37407	Rate = 0.073863
# 	['Very Poor']
#
# Node 5:
# 	Count = 44461	Rate = 0.286453
# 	['Poor']
#
#
#
# Variable: MAINHEATC_ENV_EFF
# p-value: 0.000000
# Chi2: 77894.222317
#
# Node 1:
# 	Count = 97068	Rate = 0.744303
# 	['<missing>', 'Good']
#
# Node 2:
# 	Count = 87452	Rate = 0.418149
# 	['Average']
#
# Node 3:
# 	Count = 18446	Rate = 0.981351
# 	['Very Good']
#
# Node 4:
# 	Count = 37407	Rate = 0.073863
# 	['Very Poor']
#
# Node 5:
# 	Count = 44461	Rate = 0.286453
# 	['Poor']
#
#
#
# Variable: LIGHTING_ENERGY_EFF
# p-value: 0.000000
# Chi2: 22877.956355
#
# Node 1:
# 	Count = 92196	Rate = 0.678327
# 	['<missing>', 'Very Good']
#
# Node 2:
# 	Count = 106014	Rate = 0.491284
# 	['Good', 'Average']
#
# Node 3:
# 	Count = 86624	Rate = 0.320870
# 	['Very Poor', 'Poor']
#
#
#
# Variable: LIGHTING_ENV_EFF
# p-value: 0.000000
# Chi2: 22884.471823
#
# Node 1:
# 	Count = 92277	Rate = 0.678446
# 	['<missing>', 'Very Good']
#
# Node 2:
# 	Count = 105888	Rate = 0.490924
# 	['Good', 'Average']
#
# Node 3:
# 	Count = 86669	Rate = 0.321095
# 	['Very Poor', 'Poor']
#
#
#
# Variable: MAIN_FUEL
# p-value: 0.000000
# Chi2: 47504.165365
#
# Node 1:
# 	Count = 108324	Rate = 0.689395
# 	['<missing>', 'oil (community)', 'wood chips', 'mains gas - this is for backwards compatibility only and should not be used']
#
# Node 2:
# 	Count = 14072	Rate = 0.024801
# 	['bioethanol', 'waste combustion (community)', 'house coal - this is for backwards compatibility only and should not be used', 'biodiesel from any biomass source', 'wood pellets in bags for secondary heating', 'appliances able to use mineral oil or liquid biofuel', 'bottled LPG', 'To be used only when there is no heating/hot-water system', 'wood logs', 'bulk wood pellets', 'B30K (not community)', 'smokeless coal', 'LPG (not community)', 'dual fuel - mineral + wood', 'anthracite', 'house coal (not community)']
#
# Node 3:
# 	Count = 6330	Rate = 0.946445
# 	['LPG (community)', 'Community heating schemes: heat from boilers - biomass', 'mains gas (community)', 'electricity (community)', 'biomass (community)', 'Electricity: electricity, unspecified tariff', 'B30D (community)']
#
# Node 4:
# 	Count = 97320	Rate = 0.465197
# 	['mains gas (not community)', 'LPG special condition', 'biomass - this is for backwards compatibility only and should not be used']
#
# Node 5:
# 	Count = 20585	Rate = 0.156619
# 	['waste combustion - this is for backwards compatibility only and should not be used', 'INVALID!', 'LPG - this is for backwards compatibility only and should not be used', 'oil (not community)']
#
# Node 6:
# 	Count = 38203	Rate = 0.337722
# 	['oil - this is for backwards compatibility only and should not be used', 'electricity - this is for backwards compatibility only and should not be used', 'electricity (not community)']
#
#
#
# Variable: HEAT_LOSS_CORRIDOOR
# p-value: 0.000000
# Chi2: 20408.680315
#
# Node 1:
# 	Count = 228046	Rate = 0.436193
# 	['<missing>']
#
# Node 2:
# 	Count = 45336	Rate = 0.711730
# 	['no corridor', 'unheated corridor']
#
# Node 3:
# 	Count = 11452	Rate = 0.932414
# 	['heated corridor']
#
#
#
# Variable: MECHANICAL_VENTILATION
# p-value: 0.000000
# Chi2: 40864.225362
#
# Node 1:
# 	Count = 47718	Rate = 0.922168
# 	['<missing>']
#
# Node 2:
# 	Count = 237116	Rate = 0.415042
# 	['natural', 'mechanical, supply and extract', 'mechanical, extract only']
# Variable: SECONDHEAT_DESCRIPTION
# p-value: 0.000000
# Chi2: 77515.269337
#
# Node 1:
# 	Count = 148827	Rate = 0.733886
# 	['<missing>', 'Hot-Water-Only Systems, gas', 'Room heaters, |Gwresogyddion ystafell, |electric|trydan', 'Room heaters, |Gwresogyddion ystafell, |mains gas|nwy prif gyflenwad', 'Electric Underfloor Heating (Standard tariff), electric', 'None|Dim', 'Room heaters, |Gwresogyddion ystafell, |wood logs|logiau coed', 'Room heaters, bulk wood pellets', 'Room heaters, |Gwresogyddion ystafell, |dual fuel (mineral and wood)|dau danwydd (mwynau a choed)', 'Room heaters, |Gwresogyddion ystafell, |wood chips|asglodion coed', 'None']
#
# Node 2:
# 	Count = 39114	Rate = 0.432556
# 	['Room heaters, electric', 'Portable electric heaters(assumed)', 'Room heaters, wood chips', 'none', 'Gwresogyddion ystafell, logiau coed', 'Room heaters, wood pellets', 'Dim']
#
# Node 3:
# 	Count = 71841	Rate = 0.204883
# 	['Gwresogyddion ystafell, trydan', 'Portable electric heaters', 'Room heaters, mains gas', 'Gwresogyddion trydan cludadwy (rhagdybiaeth)', 'Room heaters, bioethanol', 'From main system, no cylinderstat', 'Room heaters. Electric', 'From main system', 'Room heaters, wood logs', 'Gas instantaneous at point of use', 'Portable electric heaters (assumed)', 'Room heaters, electricity', 'Mains Gas room heaters, gas', 'Electric immersion, off-peak']
#
# Node 4:
# 	Count = 25052	Rate = 0.062151
# 	['Gwresogyddion ystafell, dau danwydd (mwynau a choed)', 'Room heaters, bulk LPG', 'Community scheme with CHP', 'From secondary system', 'Room heaters, heating oil', 'From secondary system, no cylinderstat', 'Gas/LPG boiler pre-1998 with balanced or open-flue, gas', 'Room heaters. House Coal', 'Gas/LPG boiler pre-1998, with fan-assisted flue, gas', 'Gwresogyddion ystafell, electric', 'Room heaters. Anthracite', 'Gwresogyddion ystafell, tanwydd di-fwg', 'Room heaters, smokeless coal', 'Room heaters, bioethanol from any biomass source', 'Gwresogyddion ystafell, nwy prif gyflenwad', 'Gwresogyddion ystafell, LPG', 'Room heaters. Wood Logs', 'Gwresogyddion ystafell, glo', 'LPG room heaters, Gas', 'Electric immersion, standard tariff', 'Gas/LPG boiler 1998 or later, gas', 'Room heaters. Oil', 'Room heaters, lpg', 'LPG room heaters, gas', 'Gwresogyddion ystafell, dual fuel (mineral and wood)', 'Room heaters,', 'Room heaters, anthracite', 'Room heaters, bottled LPG', 'Room heaters, coal', 'Room heaters, smokeless fuel', 'Room heaters, oil', 'Electric instantaneous at point of use', 'Gas multipoint', 'Room heaters. Dual fuel appliance (mineral and wood)', 'Room heaters, LPG', 'Room heaters, bottled gas', 'Room heaters, dual fuel (mineral and wood)', 'Room heaters, dual fuel(mineral and wood)']
#
#
#
# Variable: LIGHTING_DESCRIPTION
# p-value: 0.000000
# Chi2: 25921.652329
#
# Node 1:
# 	Count = 141589	Rate = 0.514228
# 	['<missing>', 'low energy lighting 90% of fixed outlets', 'low energy lighting 100% of fixed outlets', 'low energy lighting 80% of fixed outlets', 'low energy lighting 50% of fixed outlets', 'low energy lighting 70% of fixed outlets', 'low energy lighting 40% of fixed outlets', 'low energy lighting 30% of fixed outlets', 'low energy lighting 60% of fixed outlets']
#
# Node 2:
# 	Count = 95179	Rate = 0.335452
# 	['low energy lighting 0% of fixed outlets', 'low energy lighting 10% of fixed outlets', 'no low energy lighting', 'low energy lighting 20% of fixed outlets']
#
# Node 3:
# 	Count = 48066	Rate = 0.783922
# 	['low energy lighting in all fixed outlets']

# %%
# %store chaid_dict
# Out:
# Stored 'chaid_dict' (dict)
